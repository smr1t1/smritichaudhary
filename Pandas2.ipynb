# %% [markdown]
# # Pandas

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('imdb_data.csv')
df.shape
# Out:
# (3000, 23)

# %%
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2  Under the direction of a ruthless instructor, ...   64.299990  ...
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4  Marine Boy is the story of a former national s...    1.148070  ...
#
#   release_date runtime                                   spoken_languages  \
# 0      2/20/15    93.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1       8/6/04   113.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2     10/10/14   105.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       3/9/12   122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 4       2/5/09   118.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]
#
#      status                                            tagline  \
# 0  Released  The Laws of Space and Time are About to be Vio...
# 1  Released  It can take a lifetime to find true love; she'...
# 2  Released    The road to greatness can take you to the edge.
# 3  Released                                                NaN
# 4  Released                                                NaN
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                NaN
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970
#
# [5 rows x 23 columns]

# %%
df.tail(10)
# Out:
#         id                              belongs_to_collection    budget  \
# 2990  2991                                                NaN         0
# 2991  2992  [{'id': 107469, 'name': 'Save The Last Dance C...  13000000
# 2992  2993                                                NaN   1135654
# 2993  2994                                                NaN  60000000
# 2994  2995                                                NaN         0
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# 2990  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 2991  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 2992  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2993  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2994                      [{'id': 18, 'name': 'Drama'}]
# 2995  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#                                   homepage    imdb_id original_language  \
# 2990                                   NaN  tt0118663                en
# 2991                                   NaN  tt0206275                en
# 2992                                   NaN  tt0015400                en
# 2993  http://www.theterminal-themovie.com/  tt0362227                en
# 2994                                   NaN  tt0105327                en
# 2995                                   NaN  tt0109403                en
# 2996                                   NaN  tt2364975                sv
# 2997                                   NaN  tt0116908                en
# 2998        http://www.alongcamepolly.com/  tt0343135                en
# 2999      http://www.abductionthefilm.com/  tt1600195                en
#
#                original_title  \
# 2990                 B.A.P.S.
# 2991      Save the Last Dance
# 2992      The Thief of Bagdad
# 2993             The Terminal
# 2994              School Ties
# 2995                  Chasers
# 2996              Vi är bäst!
# 2997  The Long Kiss Goodnight
# 2998         Along Came Polly
# 2999                Abduction
#
#                                                overview  popularity  ...  \
# 2990  Can two clueless Georgia homegirls with big he...    1.560980  ...
# 2991  A white midwestern girl moves to Chicago, wher...    4.794088  ...
# 2992  A recalcitrant thief vies with a duplicitous M...    3.878515  ...
# 2993  Viktor Navorski is a man without a country; hi...   14.092373  ...
# 2994  When David Greene receives a football scholars...    7.438381  ...
# 2995  Military men Rock Reilly and Eddie Devane are ...    9.853270  ...
# 2996  Three girls in 1980s Stockholm decide to form ...    3.727996  ...
# 2997  Samantha Caine, suburban homemaker, is the ide...   14.482345  ...
# 2998  Reuben Feffer is a guy who's spent his entire ...   15.725542  ...
# 2999  A young man sets out to uncover the truth abou...   10.512109  ...
#
#      release_date runtime                                   spoken_languages  \
# 2990      3/28/97    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2991      1/12/01   112.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2992      3/18/24   149.0       [{'iso_639_1': 'xx', 'name': 'No Language'}]
# 2993      6/17/04   128.0  [{'iso_639_1': 'bg', 'name': 'български език'}...
# 2994      9/18/92   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2995      4/22/94   102.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2996      3/28/13   102.0           [{'iso_639_1': 'sv', 'name': 'svenska'}]
# 2997     10/11/96   120.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2998      1/16/04    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2999      9/22/11   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#         status                                            tagline  \
# 2990  Released                These Pretty Women... Are Clueless!
# 2991  Released        The Only Person You Need To Be Is Yourself.
# 2992  Released                         "Happiness Must Be Earned"
# 2993  Released                                   Life is waiting.
# 2994  Released  Just because you’re accepted doesn’t mean you ...
# 2995  Released  It was supposed to be a routine prisoner trans...
# 2996  Released                                                NaN
# 2997  Released               What's forgotten is not always gone.
# 2998  Released  For the most cautious man on Earth, life is ab...
# 2999  Released          They stole his life. He's taking it back.
#
#                         title  \
# 2990                 B.A.P.S.
# 2991      Save the Last Dance
# 2992      The Thief of Bagdad
# 2993             The Terminal
# 2994              School Ties
# 2995                  Chasers
# 2996         We Are the Best!
# 2997  The Long Kiss Goodnight
# 2998         Along Came Polly
# 2999                Abduction
#
#                                                Keywords  \
# 2990  [{'id': 1437, 'name': 'burglar'}, {'id': 1946,...
# 2991  [{'id': 4118, 'name': 'ballet dancer'}, {'id':...
# 2992  [{'id': 255, 'name': 'male nudity'}, {'id': 14...
# 2993  [{'id': 242, 'name': 'new york'}, {'id': 822, ...
# 2994  [{'id': 6075, 'name': 'sport'}, {'id': 10144, ...
# 2995  [{'id': 378, 'name': 'prison'}, {'id': 572, 'n...
# 2996  [{'id': 1192, 'name': 'sweden'}, {'id': 4470, ...
# 2997  [{'id': 441, 'name': 'assassination'}, {'id': ...
# 2998  [{'id': 966, 'name': 'beach'}, {'id': 2676, 'n...
# 2999  [{'id': 591, 'name': 'cia'}, {'id': 822, 'name...
#
#                                                    cast  \
# 2990  [{'cast_id': 3, 'character': 'Nisi', 'credit_i...
# 2991  [{'cast_id': 18, 'character': 'Sara Johnson', ...
# 2992  [{'cast_id': 3, 'character': 'The Thief of Bag...
# 2993  [{'cast_id': 4, 'character': 'Viktor Navorski'...
# 2994  [{'cast_id': 2, 'character': 'David Greene', '...
# 2995  [{'cast_id': 2, 'character': 'Rock Reilly', 'c...
# 2996  [{'cast_id': 5, 'character': 'Bobo', 'credit_i...
# 2997  [{'cast_id': 10, 'character': 'Samantha Caine ...
# 2998  [{'cast_id': 8, 'character': 'Reuben Feffer', ...
# 2999  [{'cast_id': 2, 'character': 'Nathan Harper', ...
#
#                                                    crew    revenue
# 2990  [{'credit_id': '52fe477b9251416c7509af57', 'de...    7240837
# 2991  [{'credit_id': '52fe4533c3a36847f80c1c6b', 'de...   91038276
# 2992  [{'credit_id': '52fe45bec3a368484e06c70b', 'de...    1213880
# 2993  [{'credit_id': '52fe4259c3a36847f8017699', 'de...  219417255
# 2994  [{'credit_id': '5637777ac3a3681b4d01f9f5', 'de...   14715067
# 2995  [{'credit_id': '52fe4494c3a368484e02ac7d', 'de...    1596687
# 2996  [{'credit_id': '5716b72ac3a3686678012c84', 'de...     180590
# 2997  [{'credit_id': '52fe443a9251416c7502d579', 'de...   89456761
# 2998  [{'credit_id': '556f817b9251410866000a63', 'de...  171963386
# 2999  [{'credit_id': '5391990d0e0a260fb5001629', 'de...   82087155
#
# [10 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
#  14  runtime                2998 non-null   float64
#  15  spoken_languages       2980 non-null   object
#  16  status                 3000 non-null   object
#  17  tagline                2403 non-null   object
#  18  title                  3000 non-null   object
#  19  Keywords               2724 non-null   object
#  20  cast                   2987 non-null   object
#  21  crew                   2984 non-null   object
#  22  revenue                3000 non-null   int64
# dtypes: float64(2), int64(3), object(18)
# memory usage: 539.2+ KB

# %%
df.describe()
# Out:
#                 id        budget   popularity      runtime       revenue
# count  3000.000000  3.000000e+03  3000.000000  2998.000000  3.000000e+03
# mean   1500.500000  2.253133e+07     8.463274   107.856571  6.672585e+07
# std     866.169729  3.702609e+07    12.104000    22.086434  1.375323e+08
# min       1.000000  0.000000e+00     0.000001     0.000000  1.000000e+00
# 25%     750.750000  0.000000e+00     4.018053    94.000000  2.379808e+06
# 50%    1500.500000  8.000000e+06     7.374861   104.000000  1.680707e+07
# 75%    2250.250000  2.900000e+07    10.890983   118.000000  6.891920e+07
# max    3000.000000  3.800000e+08   294.337037   338.000000  1.519558e+09

# %%
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2  Under the direction of a ruthless instructor, ...   64.299990  ...
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4  Marine Boy is the story of a former national s...    1.148070  ...
#
#   release_date runtime                                   spoken_languages  \
# 0      2/20/15    93.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1       8/6/04   113.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2     10/10/14   105.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       3/9/12   122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 4       2/5/09   118.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]
#
#      status                                            tagline  \
# 0  Released  The Laws of Space and Time are About to be Vio...
# 1  Released  It can take a lifetime to find true love; she'...
# 2  Released    The road to greatness can take you to the edge.
# 3  Released                                                NaN
# 4  Released                                                NaN
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                NaN
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970
#
# [5 rows x 23 columns]

# %%
df.iloc[:5,-3:]
# Out:
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970

# %%
df.loc[50:60,['budget','genres','runtime']]
# Out:
#        budget                                             genres  runtime
# 50     560000  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...    102.0
# 51   12000000  [{'id': 12, 'name': 'Adventure'}, {'id': 35, '...    160.0
# 52          0  [{'id': 12, 'name': 'Adventure'}, {'id': 10751...     97.0
# 53          0  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...     98.0
# 54   20000000                     [{'id': 28, 'name': 'Action'}]    107.0
# 55          0  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...     95.0
# 56          0  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...     97.0
# 57  125000000  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...    125.0
# 58          0  [{'id': 10402, 'name': 'Music'}, {'id': 10749,...     95.0
# 59   14000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...     95.0
# 60  150000000  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...    144.0

# %%
df.loc[:3,['budget','genres','runtime']]
# Out:
#      budget                                             genres  runtime
# 0  14000000                     [{'id': 35, 'name': 'Comedy'}]     93.0
# 1  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...    113.0
# 2   3300000                      [{'id': 18, 'name': 'Drama'}]    105.0
# 3   1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...    122.0

# %%
df[0:10]
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
# 5   6                                                NaN   8000000
# 6   7                                                NaN  14000000
# 7   8                                                NaN         0
# 8   9  [{'id': 256377, 'name': 'The Muppet Collection...         0
# 9  10                                                NaN   6000000
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 5  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 6  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 7                [{'id': 99, 'name': 'Documentary'}]
# 8  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 9  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
#
#                              homepage    imdb_id original_language  \
# 0                                 NaN  tt2637294                en
# 1                                 NaN  tt0368933                en
# 2   http://sonyclassics.com/whiplash/  tt2582802                en
# 3          http://kahaanithefilm.com/  tt1821480                hi
# 4                                 NaN  tt1380152                ko
# 5                                 NaN  tt0093743                en
# 6  http://www.thepossessionmovie.com/  tt0431021                en
# 7                                 NaN  tt0391024                en
# 8                                 NaN  tt0117110                en
# 9                                 NaN  tt0310281                en
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
# 5    Pinocchio and the Emperor of the Night
# 6                            The Possession
# 7                              Control Room
# 8                    Muppet Treasure Island
# 9                             A Mighty Wind
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2  Under the direction of a ruthless instructor, ...   64.299990  ...
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4  Marine Boy is the story of a former national s...    1.148070  ...
# 5  Pinocchio and his friends, a glow worm and a m...    0.743274  ...
# 6  A young girl buys an antique box at a yard sal...    7.286477  ...
# 7  A chronicle which provides a rare window into ...    1.949044  ...
# 8  After telling the story of Flint's last journe...    6.902423  ...
# 9  In "A Mighty Wind", director Christopher Guest...    4.672036  ...
#
#   release_date runtime                                   spoken_languages  \
# 0      2/20/15    93.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1       8/6/04   113.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2     10/10/14   105.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       3/9/12   122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 4       2/5/09   118.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]
# 5       8/6/87    83.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 6      8/30/12    92.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 7      1/15/04    84.0  [{'iso_639_1': 'ar', 'name': 'العربية'}, {'iso...
# 8      2/16/96   100.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 9      4/16/03    91.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released  The Laws of Space and Time are About to be Vio...
# 1  Released  It can take a lifetime to find true love; she'...
# 2  Released    The road to greatness can take you to the edge.
# 3  Released                                                NaN
# 4  Released                                                NaN
# 5  Released                                                NaN
# 6  Released               Fear The Demon That Doesn't Fear God
# 7  Released              Different channels. Different truths.
# 8  Released                        Set sail for Muppet mayhem!
# 9  Released           Back together for the first time, again.
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
# 5    Pinocchio and the Emperor of the Night
# 6                            The Possession
# 7                              Control Room
# 8                    Muppet Treasure Island
# 9                             A Mighty Wind
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7  [{'id': 917, 'name': 'journalism'}, {'id': 163...
# 8  [{'id': 2041, 'name': 'island'}, {'id': 4418, ...
# 9  [{'id': 11800, 'name': 'mockumentary'}, {'id':...
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
# 5  [{'cast_id': 6, 'character': 'Pinocchio (voice...
# 6  [{'cast_id': 23, 'character': 'Clyde', 'credit...
# 7  [{'cast_id': 2, 'character': 'Himself', 'credi...
# 8  [{'cast_id': 1, 'character': 'Long John Silver...
# 9  [{'cast_id': 24, 'character': 'Jonathan Steinb...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970
# 5  [{'credit_id': '52fe46f49251416c9106558b', 'de...   3261638
# 6  [{'credit_id': '52fe4981c3a368484e12ee29', 'de...  85446075
# 7  [{'credit_id': '52fe47a69251416c750a0daf', 'de...   2586511
# 8  [{'credit_id': '52fe43c89251416c7501deb3', 'de...  34327391
# 9  [{'credit_id': '52fe45609251416c750545b3', 'de...  18750246
#
# [10 rows x 23 columns]

# %%
df[['original_language','release_date','cast']]
# Out:
#      original_language release_date  \
# 0                   en      2/20/15
# 1                   en       8/6/04
# 2                   en     10/10/14
# 3                   hi       3/9/12
# 4                   ko       2/5/09
# ...                ...          ...
# 2995                en      4/22/94
# 2996                sv      3/28/13
# 2997                en     10/11/96
# 2998                en      1/16/04
# 2999                en      9/22/11
#
#                                                    cast
# 0     [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1     [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2     [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3     [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4     [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
# ...                                                 ...
# 2995  [{'cast_id': 2, 'character': 'Rock Reilly', 'c...
# 2996  [{'cast_id': 5, 'character': 'Bobo', 'credit_i...
# 2997  [{'cast_id': 10, 'character': 'Samantha Caine ...
# 2998  [{'cast_id': 8, 'character': 'Reuben Feffer', ...
# 2999  [{'cast_id': 2, 'character': 'Nathan Harper', ...
#
# [3000 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
df['original_language'] == 'en'
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 2995     True
# 2996    False
# 2997     True
# 2998     True
# 2999     True
# Name: original_language, Length: 3000, dtype: bool

# %%
english_movies = df[df['original_language'] == 'en']
english_movies.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 5   6                                                NaN   8000000
# 6   7                                                NaN  14000000
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 5  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 6  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
#
#                              homepage    imdb_id original_language  \
# 0                                 NaN  tt2637294                en
# 1                                 NaN  tt0368933                en
# 2   http://sonyclassics.com/whiplash/  tt2582802                en
# 5                                 NaN  tt0093743                en
# 6  http://www.thepossessionmovie.com/  tt0431021                en
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 5    Pinocchio and the Emperor of the Night
# 6                            The Possession
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2  Under the direction of a ruthless instructor, ...   64.299990  ...
# 5  Pinocchio and his friends, a glow worm and a m...    0.743274  ...
# 6  A young girl buys an antique box at a yard sal...    7.286477  ...
#
#   release_date runtime                          spoken_languages    status  \
# 0      2/20/15    93.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1       8/6/04   113.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2     10/10/14   105.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 5       8/6/87    83.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 6      8/30/12    92.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline  \
# 0  The Laws of Space and Time are About to be Vio...
# 1  It can take a lifetime to find true love; she'...
# 2    The road to greatness can take you to the edge.
# 5                                                NaN
# 6               Fear The Demon That Doesn't Fear God
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 5    Pinocchio and the Emperor of the Night
# 6                            The Possession
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 5                                                NaN
# 6                                                NaN
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 5  [{'cast_id': 6, 'character': 'Pinocchio (voice...
# 6  [{'cast_id': 23, 'character': 'Clyde', 'credit...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
# 5  [{'credit_id': '52fe46f49251416c9106558b', 'de...   3261638
# 6  [{'credit_id': '52fe4981c3a368484e12ee29', 'de...  85446075
#
# [5 rows x 23 columns]

# %%
english_movies.shape
# Out:
# (2575, 23)

# %%
non_english_movies = df[df['original_language'] != 'en']
non_english_movies.head()
# Out:
#     id belongs_to_collection    budget  \
# 3    4                   NaN   1200000
# 4    5                   NaN         0
# 15  16                   NaN    500000
# 30  31                   NaN  13000000
# 31  32                   NaN         0
#
#                                                genres  \
# 3   [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4   [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 15  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 30  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 31  [{'id': 9648, 'name': 'Mystery'}, {'id': 18, '...
#
#                                  homepage    imdb_id original_language  \
# 3              http://kahaanithefilm.com/  tt1821480                hi
# 4                                     NaN  tt1380152                ko
# 15  http://skinningmovie.com/synopsis.htm  tt1129437                sr
# 30                                    NaN  tt1675434                fr
# 31            http://www.cache-derfilm.at  tt0387898                fr
#
#    original_title                                           overview  \
# 3         Kahaani  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...
# 4            마린보이  Marine Boy is the story of a former national s...
# 15        Šišanje  Novica is a mathematics champion in a Belgrade...
# 30   Intouchables  A true story of two men who should never have ...
# 31          Caché  A married couple is terrorized by a series of ...
#
#     popularity  ... release_date runtime  \
# 3     3.174936  ...       3/9/12   122.0
# 4     1.148070  ...       2/5/09   118.0
# 15    1.018477  ...      10/6/10    97.0
# 30   16.086919  ...      11/2/11   112.0
# 31    5.695860  ...       5/2/05   117.0
#
#                                      spoken_languages    status  \
# 3   [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 4            [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]  Released
# 15            [{'iso_639_1': 'sr', 'name': 'Srpski'}]  Released
# 30  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 31          [{'iso_639_1': 'fr', 'name': 'Français'}]  Released
#
#                                               tagline             title  \
# 3                                                 NaN           Kahaani
# 4                                                 NaN        Marine Boy
# 15  Life is sometimes rude game: one mistake can b...          Skinning
# 30  Sometimes you have to reach into someone else'...  The Intouchables
# 31                                                NaN             Caché
#
#                                              Keywords  \
# 3   [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                 NaN
# 15  [{'id': 379, 'name': 'skinhead'}, {'id': 7492,...
# 30  [{'id': 3230, 'name': 'male friendship'}, {'id...
# 31  [{'id': 90, 'name': 'paris'}, {'id': 213, 'nam...
#
#                                                  cast  \
# 3   [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4   [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
# 15  [{'cast_id': 1001, 'character': 'Novica', 'cre...
# 30  [{'cast_id': 6, 'character': 'Philippe', 'cred...
# 31  [{'cast_id': 2, 'character': 'Georges Laurent'...
#
#                                                  crew    revenue
# 3   [{'credit_id': '52fe48779251416c9108d6eb', 'de...   16000000
# 4   [{'credit_id': '52fe464b9251416c75073b43', 'de...    3923970
# 15  [{'credit_id': '52fe4927c3a36847f818bb5f', 'de...        198
# 30  [{'credit_id': '52fe4967c3a368484e129b63', 'de...  426480871
# 31  [{'credit_id': '52fe4244c3a36847f8011073', 'de...   36000000
#
# [5 rows x 23 columns]

# %%
long_movies = df[df['runtime'] > 120]
long_movies[['title','cast']]
# Out:
#                     title                                               cast
# 3                 Kahaani  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 12        American Beauty  [{'cast_id': 6, 'character': 'Lester Burnham',...
# 14        Minority Report  [{'cast_id': 5, 'character': 'Chief John Ander...
# 20          Lost in Space  [{'cast_id': 26, 'character': 'Dr. Zachary Smi...
# 33        ABCs of Death 2  [{'cast_id': 60, 'character': 'Assassin (Segme...
# ...                   ...                                                ...
# 2969         Gosford Park  [{'cast_id': 2, 'character': 'Mrs. Wilson', 'c...
# 2970        The Bodyguard  [{'cast_id': 17, 'character': 'Rachel Marron',...
# 2980     Action Hero Biju  [{'cast_id': 1, 'character': 'Sub-Inspector Bi...
# 2992  The Thief of Bagdad  [{'cast_id': 3, 'character': 'The Thief of Bag...
# 2993         The Terminal  [{'cast_id': 4, 'character': 'Viktor Navorski'...
#
# [657 rows x 2 columns]

# %%
long_movies = df[df['runtime'] > 120]
long_movies.tail()
# Out:
#         id belongs_to_collection    budget  \
# 2969  2970                   NaN  19800000
# 2970  2971                   NaN  25000000
# 2980  2981                   NaN    300000
# 2992  2993                   NaN   1135654
# 2993  2994                   NaN  60000000
#
#                                                  genres  \
# 2969  [{'id': 18, 'name': 'Drama'}, {'id': 9648, 'na...
# 2970  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
# 2980  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 2992  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2993  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
#
#                                       homepage    imdb_id original_language  \
# 2969                                       NaN  tt0280707                en
# 2970                                       NaN  tt0103855                en
# 2980  https://www.facebook.com/Actionherobiju/  tt5320514                ml
# 2992                                       NaN  tt0015400                en
# 2993      http://www.theterminal-themovie.com/  tt0362227                en
#
#            original_title                                           overview  \
# 2969         Gosford Park  Multiple storylined drama set in 1932, showing...
# 2970        The Bodyguard  A former Secret Service agent grudgingly takes...
# 2980      ആക്ഷൻ ഹീറോ ബിജു  Biju is an honest policeman who fights the inj...
# 2992  The Thief of Bagdad  A recalcitrant thief vies with a duplicitous M...
# 2993         The Terminal  Viktor Navorski is a man without a country; hi...
#
#       popularity  ... release_date runtime  \
# 2969   14.101101  ...      11/7/01   137.0
# 2970    9.805017  ...     11/25/92   129.0
# 2980    0.350207  ...       2/4/16   144.0
# 2992    3.878515  ...      3/18/24   149.0
# 2993   14.092373  ...      6/17/04   128.0
#
#                                        spoken_languages    status  \
# 2969           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2970           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2980                  [{'iso_639_1': 'ml', 'name': ''}]  Released
# 2992       [{'iso_639_1': 'xx', 'name': 'No Language'}]  Released
# 2993  [{'iso_639_1': 'bg', 'name': 'български език'}...  Released
#
#                                                 tagline                title  \
# 2969  Tea at four. Dinner at eight. Murder at midnight.         Gosford Park
# 2970  Never let her out of your sight. Never let you...        The Bodyguard
# 2980                       A ride with a police officer     Action Hero Biju
# 2992                         "Happiness Must Be Earned"  The Thief of Bagdad
# 2993                                   Life is waiting.         The Terminal
#
#                                                Keywords  \
# 2969  [{'id': 964, 'name': 'servant'}, {'id': 10594,...
# 2970  [{'id': 1156, 'name': 'sister sister relations...
# 2980  [{'id': 1252, 'name': 'suicide attempt'}, {'id...
# 2992  [{'id': 255, 'name': 'male nudity'}, {'id': 14...
# 2993  [{'id': 242, 'name': 'new york'}, {'id': 822, ...
#
#                                                    cast  \
# 2969  [{'cast_id': 2, 'character': 'Mrs. Wilson', 'c...
# 2970  [{'cast_id': 17, 'character': 'Rachel Marron',...
# 2980  [{'cast_id': 1, 'character': 'Sub-Inspector Bi...
# 2992  [{'cast_id': 3, 'character': 'The Thief of Bag...
# 2993  [{'cast_id': 4, 'character': 'Viktor Navorski'...
#
#                                                    crew    revenue
# 2969  [{'credit_id': '52fe4401c3a36847f807ceab', 'de...   87754044
# 2970  [{'credit_id': '52fe425ec3a36847f8019133', 'de...  411006740
# 2980  [{'credit_id': '56b4d47f92514112b90045f6', 'de...    2500000
# 2992  [{'credit_id': '52fe45bec3a368484e06c70b', 'de...    1213880
# 2993  [{'credit_id': '52fe4259c3a36847f8017699', 'de...  219417255
#
# [5 rows x 23 columns]

# %%
(df['original_language'] == 'en') & (df['runtime'] > 120)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2995    False
# 2996    False
# 2997    False
# 2998    False
# 2999    False
# Length: 3000, dtype: bool

# %%
long_english_movies = df[(df['original_language'] == 'en') & (df['runtime'] > 120)]
long_english_movies.head()
# Out:
#     id                              belongs_to_collection     budget  \
# 12  13                                                NaN   15000000
# 14  15                                                NaN  102000000
# 20  21                                                NaN   80000000
# 33  34  [{'id': 207632, 'name': 'The ABCs of Death Col...          0
# 37  38                                                NaN   50000000
#
#                                                genres  \
# 12                      [{'id': 18, 'name': 'Drama'}]
# 14  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 20  [{'id': 12, 'name': 'Adventure'}, {'id': 10751...
# 33                     [{'id': 27, 'name': 'Horror'}]
# 37  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
#
#                          homepage    imdb_id original_language  \
# 12  http://www.dreamworks.com/ab/  tt0169547                en
# 14                            NaN  tt0181689                en
# 20                            NaN  tt0120738                en
# 33                            NaN  tt2926810                en
# 37                            NaN  tt0114069                en
#
#      original_title                                           overview  \
# 12  American Beauty  Lester Burnham, a depressed suburban father in...
# 14  Minority Report  John Anderton is a top 'Precrime' cop in the l...
# 20    Lost in Space  The prospects for continuing life on Earth in ...
# 33  ABCs of Death 2  Taking all that was great from the first insta...
# 37         Outbreak  A deadly airborne virus finds its way into the...
#
#     popularity  ... release_date runtime  \
# 12   20.726578  ...      9/15/99   122.0
# 14   20.666063  ...      6/20/02   145.0
# 20   12.000579  ...       4/3/98   130.0
# 33    8.254856  ...      10/2/14   125.0
# 37   13.676444  ...      3/10/95   127.0
#
#                                      spoken_languages    status  \
# 12           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 14  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 20           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 33  [{'iso_639_1': 'ar', 'name': 'العربية'}, {'iso...  Released
# 37  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
#
#                                               tagline            title  \
# 12                                       Look closer.  American Beauty
# 14    The system is perfect until it comes after you.  Minority Report
# 20                             Danger, Will Robinson!    Lost in Space
# 33                            Some people never learn  ABCs of Death 2
# 37  This animal carries a deadly virus... and the ...         Outbreak
#
#                                              Keywords  \
# 12  [{'id': 255, 'name': 'male nudity'}, {'id': 29...
# 14  [{'id': 476, 'name': 'self-fulfilling prophecy...
# 20  [{'id': 4379, 'name': 'time travel'}, {'id': 1...
# 33  [{'id': 9706, 'name': 'anthology'}, {'id': 187...
# 37  [{'id': 1261, 'name': 'river'}, {'id': 1402, '...
#
#                                                  cast  \
# 12  [{'cast_id': 6, 'character': 'Lester Burnham',...
# 14  [{'cast_id': 5, 'character': 'Chief John Ander...
# 20  [{'cast_id': 26, 'character': 'Dr. Zachary Smi...
# 33  [{'cast_id': 60, 'character': 'Assassin (Segme...
# 37  [{'cast_id': 1, 'character': 'Sam Daniels', 'c...
#
#                                                  crew    revenue
# 12  [{'credit_id': '52fe420ec3a36847f80007c5', 'de...  356296601
# 14  [{'credit_id': '52fe4223c3a36847f8006f3d', 'de...  358372926
# 20  [{'credit_id': '52fe433bc3a36847f80448b9', 'de...  136159423
# 33  [{'credit_id': '52fe4cd69251416c91101d73', 'de...       7171
# 37  [{'credit_id': '52fe446ac3a36847f80949d3', 'de...  189859560
#
# [5 rows x 23 columns]

# %%
long_english_movies.shape
# Out:
# (506, 23)

# %%
df.shape
# Out:
# (3000, 23)

# %%
df[['runtime', 'cast']]
# Out:
#       runtime                                               cast
# 0        93.0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1       113.0  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2       105.0  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3       122.0  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4       118.0  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
# ...       ...                                                ...
# 2995    102.0  [{'cast_id': 2, 'character': 'Rock Reilly', 'c...
# 2996    102.0  [{'cast_id': 5, 'character': 'Bobo', 'credit_i...
# 2997    120.0  [{'cast_id': 10, 'character': 'Samantha Caine ...
# 2998     90.0  [{'cast_id': 8, 'character': 'Reuben Feffer', ...
# 2999    106.0  [{'cast_id': 2, 'character': 'Nathan Harper', ...
#
# [3000 rows x 2 columns]

# %%
df['half_runtime'] = df['runtime']* 0.5
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
#
#                                             overview  popularity  ... runtime  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...    93.0
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...   113.0
# 2  Under the direction of a ruthless instructor, ...   64.299990  ...   105.0
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...   122.0
# 4  Marine Boy is the story of a former national s...    1.148070  ...   118.0
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 4           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]  Released
#
#                                              tagline  \
# 0  The Laws of Space and Time are About to be Vio...
# 1  It can take a lifetime to find true love; she'...
# 2    The road to greatness can take you to the edge.
# 3                                                NaN
# 4                                                NaN
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                NaN
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
#
#                                                 crew   revenue half_runtime
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651         46.5
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435         56.5
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000         52.5
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000         61.0
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970         59.0
#
# [5 rows x 24 columns]

# %%
df['movies_profit'] = df['revenue'] - df['budget']
df.head()
# Out:
#                                belongs_to_collection    budget  \
# 0  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2                                                NaN   3300000
# 3                                                NaN   1200000
# 4                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
#
#                                             overview  popularity  \
# 0  When Lou, who has become the "father of the In...    6.575393
# 1  Mia Thermopolis is now a college graduate and ...    8.248895
# 2  Under the direction of a ruthless instructor, ...   64.299990
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936
# 4  Marine Boy is the story of a former national s...    1.148070
#
#                         poster_path  ...  \
# 0  /tQtWuwvMf0hCc2QR2tkolwl7c3c.jpg  ...
# 1  /w9Z7A0GHEhIp7etpj0vyKOeU1Wx.jpg  ...
# 2  /lIv1QinFqz4dlp5U4lQ6HaiskOZ.jpg  ...
# 3  /aTXRaPrWSinhcmCrcfJK17urp3F.jpg  ...
# 4  /m22s7zvkVFDU9ir56PiiqIEWFdT.jpg  ...
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 4           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]  Released
#
#                                              tagline  \
# 0  The Laws of Space and Time are About to be Vio...
# 1  It can take a lifetime to find true love; she'...
# 2    The road to greatness can take you to the edge.
# 3                                                NaN
# 4                                                NaN
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                NaN
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
#
#                                                 crew   revenue half_runtime  \
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651         46.5
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435         56.5
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000         52.5
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000         61.0
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970         59.0
#
#   movies_profit
# 0      -1685349
# 1      55149435
# 2       9792000
# 3      14800000
# 4       3923970
#
# [5 rows x 24 columns]

# %%
df.head()
# Out:
#                                belongs_to_collection    budget  \
# 0  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2                                                NaN   3300000
# 3                                                NaN   1200000
# 4                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
#
#                                             overview  popularity  \
# 0  When Lou, who has become the "father of the In...    6.575393
# 1  Mia Thermopolis is now a college graduate and ...    8.248895
# 2  Under the direction of a ruthless instructor, ...   64.299990
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936
# 4  Marine Boy is the story of a former national s...    1.148070
#
#                         poster_path  ...  \
# 0  /tQtWuwvMf0hCc2QR2tkolwl7c3c.jpg  ...
# 1  /w9Z7A0GHEhIp7etpj0vyKOeU1Wx.jpg  ...
# 2  /lIv1QinFqz4dlp5U4lQ6HaiskOZ.jpg  ...
# 3  /aTXRaPrWSinhcmCrcfJK17urp3F.jpg  ...
# 4  /m22s7zvkVFDU9ir56PiiqIEWFdT.jpg  ...
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 4           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]  Released
#
#                                              tagline  \
# 0  The Laws of Space and Time are About to be Vio...
# 1  It can take a lifetime to find true love; she'...
# 2    The road to greatness can take you to the edge.
# 3                                                NaN
# 4                                                NaN
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                NaN
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
#
#                                                 crew   revenue half_runtime  \
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651         46.5
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435         56.5
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000         52.5
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000         61.0
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970         59.0
#
#   movies_profit
# 0      -1685349
# 1      55149435
# 2       9792000
# 3      14800000
# 4       3923970
#
# [5 rows x 24 columns]

# %%
df.describe()
# Out:
#              budget   popularity      runtime       revenue  half_runtime  \
# count  3.000000e+03  3000.000000  2998.000000  3.000000e+03   2998.000000
# mean   2.253133e+07     8.463274   107.856571  6.672585e+07     53.928286
# std    3.702609e+07    12.104000    22.086434  1.375323e+08     11.043217
# min    0.000000e+00     0.000001     0.000000  1.000000e+00      0.000000
# 25%    0.000000e+00     4.018053    94.000000  2.379808e+06     47.000000
# 50%    8.000000e+06     7.374861   104.000000  1.680707e+07     52.000000
# 75%    2.900000e+07    10.890983   118.000000  6.891920e+07     59.000000
# max    3.800000e+08   294.337037   338.000000  1.519558e+09    169.000000
#
#        movies_profit
# count   3.000000e+03
# mean    4.419452e+07
# std     1.123274e+08
# min    -1.074474e+08
# 25%     1.795200e+04
# 50%     6.121122e+06
# 75%     4.143293e+07
# max     1.316249e+09

# %%
df.drop(['half_runtime','poster_path'], axis=1 , inplace = True)
df.drop(['crew'], axis=1 , inplace = True)
df.head()
# Out:
#                                belongs_to_collection    budget  \
# 0  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2                                                NaN   3300000
# 3                                                NaN   1200000
# 4                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
#
#                                             overview  popularity  \
# 0  When Lou, who has become the "father of the In...    6.575393
# 1  Mia Thermopolis is now a college graduate and ...    8.248895
# 2  Under the direction of a ruthless instructor, ...   64.299990
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936
# 4  Marine Boy is the story of a former national s...    1.148070
#
#                                 production_companies  ... release_date  \
# 0  [{'name': 'Paramount Pictures', 'id': 4}, {'na...  ...      2/20/15
# 1        [{'name': 'Walt Disney Pictures', 'id': 2}]  ...       8/6/04
# 2  [{'name': 'Bold Films', 'id': 2266}, {'name': ...  ...     10/10/14
# 3                                                NaN  ...       3/9/12
# 4                                                NaN  ...       2/5/09
#
#   runtime                                   spoken_languages    status  \
# 0    93.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1   113.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2   105.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3   122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 4   118.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]  Released
#
#                                              tagline  \
# 0  The Laws of Space and Time are About to be Vio...
# 1  It can take a lifetime to find true love; she'...
# 2    The road to greatness can take you to the edge.
# 3                                                NaN
# 4                                                NaN
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                NaN
#
#                                                 cast   revenue  movies_profit
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...  12314651       -1685349
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...  95149435       55149435
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...  13092000        9792000
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...  16000000       14800000
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...   3923970        3923970
#
# [5 rows x 21 columns]

# %%
df['budget'].sum()
# Out:
# 67594002330

# %%
df.loc[:1,'revenue'] = np.nan
df.iloc[:5]
# Out:
#                                belongs_to_collection    budget  \
# 0  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2                                                NaN   3300000
# 3                                                NaN   1200000
# 4                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
#
#                                             overview  popularity  \
# 0  When Lou, who has become the "father of the In...    6.575393
# 1  Mia Thermopolis is now a college graduate and ...    8.248895
# 2  Under the direction of a ruthless instructor, ...   64.299990
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936
# 4  Marine Boy is the story of a former national s...    1.148070
#
#                                 production_companies  ... release_date  \
# 0  [{'name': 'Paramount Pictures', 'id': 4}, {'na...  ...      2/20/15
# 1        [{'name': 'Walt Disney Pictures', 'id': 2}]  ...       8/6/04
# 2  [{'name': 'Bold Films', 'id': 2266}, {'name': ...  ...     10/10/14
# 3                                                NaN  ...       3/9/12
# 4                                                NaN  ...       2/5/09
#
#   runtime                                   spoken_languages    status  \
# 0    93.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1   113.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2   105.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3   122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 4   118.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]  Released
#
#                                              tagline  \
# 0  The Laws of Space and Time are About to be Vio...
# 1  It can take a lifetime to find true love; she'...
# 2    The road to greatness can take you to the edge.
# 3                                                NaN
# 4                                                NaN
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                NaN
#
#                                                 cast     revenue  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...         NaN
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...         NaN
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...  13092000.0
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...  16000000.0
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...   3923970.0
#
#    movies_profit
# 0       -1685349
# 1       55149435
# 2        9792000
# 3       14800000
# 4        3923970
#
# [5 rows x 21 columns]

# %%
df.set_index('budget', inplace = True)
df.head()
# Out:
#                                       belongs_to_collection  \
# budget
# 14000000  [{'id': 313576, 'name': 'Hot Tub Time Machine ...
# 40000000  [{'id': 107674, 'name': 'The Princess Diaries ...
# 3300000                                                 NaN
# 1200000                                                 NaN
# 0                                                       NaN
#
#                                                      genres  \
# budget
# 14000000                     [{'id': 35, 'name': 'Comedy'}]
# 40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 3300000                       [{'id': 18, 'name': 'Drama'}]
# 1200000   [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 0         [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                                    homepage    imdb_id original_language  \
# budget
# 14000000                                NaN  tt2637294                en
# 40000000                                NaN  tt0368933                en
# 3300000   http://sonyclassics.com/whiplash/  tt2582802                en
# 1200000          http://kahaanithefilm.com/  tt1821480                hi
# 0                                       NaN  tt1380152                ko
#
#                                     original_title  \
# budget
# 14000000                    Hot Tub Time Machine 2
# 40000000  The Princess Diaries 2: Royal Engagement
# 3300000                                   Whiplash
# 1200000                                    Kahaani
# 0                                             마린보이
#
#                                                    overview  popularity  \
# budget
# 14000000  When Lou, who has become the "father of the In...    6.575393
# 40000000  Mia Thermopolis is now a college graduate and ...    8.248895
# 3300000   Under the direction of a ruthless instructor, ...   64.299990
# 1200000   Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936
# 0         Marine Boy is the story of a former national s...    1.148070
#
#                                        production_companies  \
# budget
# 14000000  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 40000000        [{'name': 'Walt Disney Pictures', 'id': 2}]
# 3300000   [{'name': 'Bold Films', 'id': 2266}, {'name': ...
# 1200000                                                 NaN
# 0                                                       NaN
#
#                                        production_countries release_date  \
# budget
# 14000000  [{'iso_3166_1': 'US', 'name': 'United States o...      2/20/15
# 40000000  [{'iso_3166_1': 'US', 'name': 'United States o...       8/6/04
# 3300000   [{'iso_3166_1': 'US', 'name': 'United States o...     10/10/14
# 1200000             [{'iso_3166_1': 'IN', 'name': 'India'}]       3/9/12
# 0             [{'iso_3166_1': 'KR', 'name': 'South Korea'}]       2/5/09
#
#           runtime                                   spoken_languages  \
# budget
# 14000000     93.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 40000000    113.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3300000     105.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1200000     122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 0           118.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]
#
#             status                                            tagline  \
# budget
# 14000000  Released  The Laws of Space and Time are About to be Vio...
# 40000000  Released  It can take a lifetime to find true love; she'...
# 3300000   Released    The road to greatness can take you to the edge.
# 1200000   Released                                                NaN
# 0         Released                                                NaN
#
#                                              title  \
# budget
# 14000000                    Hot Tub Time Machine 2
# 40000000  The Princess Diaries 2: Royal Engagement
# 3300000                                   Whiplash
# 1200000                                    Kahaani
# 0                                       Marine Boy
#
#                                                    Keywords  \
# budget
# 14000000  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 40000000  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 3300000   [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 1200000   [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 0                                                       NaN
#
#                                                        cast     revenue  \
# budget
# 14000000  [{'cast_id': 4, 'character': 'Lou', 'credit_id...         NaN
# 40000000  [{'cast_id': 1, 'character': 'Mia Thermopolis'...         NaN
# 3300000   [{'cast_id': 5, 'character': 'Andrew Neimann',...  13092000.0
# 1200000   [{'cast_id': 1, 'character': 'Vidya Bagchi', '...  16000000.0
# 0         [{'cast_id': 3, 'character': 'Chun-soo', 'cred...   3923970.0
#
#           movies_profit
# budget
# 14000000       -1685349
# 40000000       55149435
# 3300000         9792000
# 1200000        14800000
# 0               3923970

# %%
df.iloc[:3]
# Out:
#                                       belongs_to_collection  \
# budget
# 14000000  [{'id': 313576, 'name': 'Hot Tub Time Machine ...
# 40000000  [{'id': 107674, 'name': 'The Princess Diaries ...
# 3300000                                                 NaN
#
#                                                      genres  \
# budget
# 14000000                     [{'id': 35, 'name': 'Comedy'}]
# 40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 3300000                       [{'id': 18, 'name': 'Drama'}]
#
#                                    homepage    imdb_id original_language  \
# budget
# 14000000                                NaN  tt2637294                en
# 40000000                                NaN  tt0368933                en
# 3300000   http://sonyclassics.com/whiplash/  tt2582802                en
#
#                                     original_title  \
# budget
# 14000000                    Hot Tub Time Machine 2
# 40000000  The Princess Diaries 2: Royal Engagement
# 3300000                                   Whiplash
#
#                                                    overview  popularity  \
# budget
# 14000000  When Lou, who has become the "father of the In...    6.575393
# 40000000  Mia Thermopolis is now a college graduate and ...    8.248895
# 3300000   Under the direction of a ruthless instructor, ...   64.299990
#
#                                        production_companies  \
# budget
# 14000000  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 40000000        [{'name': 'Walt Disney Pictures', 'id': 2}]
# 3300000   [{'name': 'Bold Films', 'id': 2266}, {'name': ...
#
#                                        production_countries release_date  \
# budget
# 14000000  [{'iso_3166_1': 'US', 'name': 'United States o...      2/20/15
# 40000000  [{'iso_3166_1': 'US', 'name': 'United States o...       8/6/04
# 3300000   [{'iso_3166_1': 'US', 'name': 'United States o...     10/10/14
#
#           runtime                          spoken_languages    status  \
# budget
# 14000000     93.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 40000000    113.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3300000     105.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                     tagline  \
# budget
# 14000000  The Laws of Space and Time are About to be Vio...
# 40000000  It can take a lifetime to find true love; she'...
# 3300000     The road to greatness can take you to the edge.
#
#                                              title  \
# budget
# 14000000                    Hot Tub Time Machine 2
# 40000000  The Princess Diaries 2: Royal Engagement
# 3300000                                   Whiplash
#
#                                                    Keywords  \
# budget
# 14000000  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 40000000  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 3300000   [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
#
#                                                        cast     revenue  \
# budget
# 14000000  [{'cast_id': 4, 'character': 'Lou', 'credit_id...         NaN
# 40000000  [{'cast_id': 1, 'character': 'Mia Thermopolis'...         NaN
# 3300000   [{'cast_id': 5, 'character': 'Andrew Neimann',...  13092000.0
#
#           movies_profit
# budget
# 14000000       -1685349
# 40000000       55149435
# 3300000         9792000

# %%
df.loc[0]
# Out:
#                                     belongs_to_collection  \
# budget
# 0                                                     NaN
# 0                                                     NaN
# 0       [{'id': 256377, 'name': 'The Muppet Collection...
# 0       [{'id': 48190, 'name': 'Revenge of the Nerds C...
# 0                                                     NaN
# ...                                                   ...
# 0                                                     NaN
# 0                                                     NaN
# 0                                                     NaN
# 0                                                     NaN
# 0                                                     NaN
#
#                                                    genres homepage    imdb_id  \
# budget
# 0       [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...      NaN  tt1380152
# 0                     [{'id': 99, 'name': 'Documentary'}]      NaN  tt0391024
# 0       [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...      NaN  tt0117110
# 0                          [{'id': 35, 'name': 'Comedy'}]      NaN  tt0093857
# 0       [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN  tt1700845
# ...                                                   ...      ...        ...
# 0       [{'id': 16, 'name': 'Animation'}, {'id': 10751...      NaN  tt0206367
# 0       [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...      NaN  tt0118663
# 0                           [{'id': 18, 'name': 'Drama'}]      NaN  tt0105327
# 0       [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...      NaN  tt0109403
# 0       [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...      NaN  tt2364975
#
#        original_language                              original_title  \
# budget
# 0                     ko                                        마린보이
# 0                     en                                Control Room
# 0                     en                      Muppet Treasure Island
# 0                     en  Revenge of the Nerds II: Nerds in Paradise
# 0                     en                         The Invisible Woman
# ...                  ...                                         ...
# 0                     en                     The Trumpet Of The Swan
# 0                     en                                    B.A.P.S.
# 0                     en                                 School Ties
# 0                     en                                     Chasers
# 0                     sv                                 Vi är bäst!
#
#                                                  overview  popularity  \
# budget
# 0       Marine Boy is the story of a former national s...    1.148070
# 0       A chronicle which provides a rare window into ...    1.949044
# 0       After telling the story of Flint's last journe...    6.902423
# 0       The members of the Lambda Lambda Lambda frater...   10.543750
# 0       In 1857, at the height of his fame and fortune...    4.183558
# ...                                                   ...         ...
# 0       The adventures of a young Trumpeter swan who c...    0.851599
# 0       Can two clueless Georgia homegirls with big he...    1.560980
# 0       When David Greene receives a football scholars...    7.438381
# 0       Military men Rock Reilly and Eddie Devane are ...    9.853270
# 0       Three girls in 1980s Stockholm decide to form ...    3.727996
#
#                                      production_companies  \
# budget
# 0                                                     NaN
# 0                                                     NaN
# 0       [{'name': 'Walt Disney Pictures', 'id': 2}, {'...
# 0       [{'name': 'Twentieth Century Fox Film Corporat...
# 0       [{'name': 'BBC Films', 'id': 288}, {'name': 'H...
# ...                                                   ...
# 0       [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 0       [{'name': 'New Line Cinema', 'id': 12}, {'name...
# 0               [{'name': 'Paramount Pictures', 'id': 4}]
# 0       [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 0       [{'name': 'Memfis Film', 'id': 321}, {'name': ...
#
#                                      production_countries release_date  \
# budget
# 0           [{'iso_3166_1': 'KR', 'name': 'South Korea'}]       2/5/09
# 0                                                     NaN      1/15/04
# 0       [{'iso_3166_1': 'US', 'name': 'United States o...      2/16/96
# 0       [{'iso_3166_1': 'US', 'name': 'United States o...      7/10/87
# 0        [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]     12/25/13
# ...                                                   ...          ...
# 0       [{'iso_3166_1': 'US', 'name': 'United States o...      5/11/01
# 0                                                     NaN      3/28/97
# 0       [{'iso_3166_1': 'US', 'name': 'United States o...      9/18/92
# 0       [{'iso_3166_1': 'US', 'name': 'United States o...      4/22/94
# 0       [{'iso_3166_1': 'DK', 'name': 'Denmark'}, {'is...      3/28/13
#
#         runtime                                   spoken_languages    status  \
# budget
# 0         118.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]  Released
# 0          84.0  [{'iso_639_1': 'ar', 'name': 'العربية'}, {'iso...  Released
# 0         100.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 0          98.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 0         111.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...         ...                                                ...       ...
# 0          75.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 0          90.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 0         106.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 0         102.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 0         102.0           [{'iso_639_1': 'sv', 'name': 'svenska'}]  Released
#
#                                                   tagline  \
# budget
# 0                                                     NaN
# 0                   Different channels. Different truths.
# 0                             Set sail for Muppet mayhem!
# 0                                           They're Back!
# 0       His greatest story was the one he could never ...
# ...                                                   ...
# 0       Sometimes being different helps you to find yo...
# 0                     These Pretty Women... Are Clueless!
# 0       Just because you’re accepted doesn’t mean you ...
# 0       It was supposed to be a routine prisoner trans...
# 0                                                     NaN
#
#                                              title  \
# budget
# 0                                       Marine Boy
# 0                                     Control Room
# 0                           Muppet Treasure Island
# 0       Revenge of the Nerds II: Nerds in Paradise
# 0                              The Invisible Woman
# ...                                            ...
# 0                          The Trumpet Of The Swan
# 0                                         B.A.P.S.
# 0                                      School Ties
# 0                                          Chasers
# 0                                 We Are the Best!
#
#                                                  Keywords  \
# budget
# 0                                                     NaN
# 0       [{'id': 917, 'name': 'journalism'}, {'id': 163...
# 0       [{'id': 2041, 'name': 'island'}, {'id': 4418, ...
# 0       [{'id': 5801, 'name': 'nerd'}, {'id': 6876, 'n...
# 0       [{'id': 5565, 'name': 'biography'}, {'id': 180...
# ...                                                   ...
# 0       [{'id': 6653, 'name': 'trumpet'}, {'id': 10407...
# 0       [{'id': 1437, 'name': 'burglar'}, {'id': 1946,...
# 0       [{'id': 6075, 'name': 'sport'}, {'id': 10144, ...
# 0       [{'id': 378, 'name': 'prison'}, {'id': 572, 'n...
# 0       [{'id': 1192, 'name': 'sweden'}, {'id': 4470, ...
#
#                                                      cast     revenue  \
# budget
# 0       [{'cast_id': 3, 'character': 'Chun-soo', 'cred...   3923970.0
# 0       [{'cast_id': 2, 'character': 'Himself', 'credi...   2586511.0
# 0       [{'cast_id': 1, 'character': 'Long John Silver...  34327391.0
# 0       [{'cast_id': 2, 'character': 'Lewis Skolnick',...  22642033.0
# 0       [{'cast_id': 7, 'character': 'Charles Dickens'...   1234254.0
# ...                                                   ...         ...
# 0       [{'cast_id': 1, 'character': 'Father', 'credit...    100202.0
# 0       [{'cast_id': 3, 'character': 'Nisi', 'credit_i...   7240837.0
# 0       [{'cast_id': 2, 'character': 'David Greene', '...  14715067.0
# 0       [{'cast_id': 2, 'character': 'Rock Reilly', 'c...   1596687.0
# 0       [{'cast_id': 5, 'character': 'Bobo', 'credit_i...    180590.0
#
#         movies_profit
# budget
# 0             3923970
# 0             2586511
# 0            34327391
# 0            22642033
# 0             1234254
# ...               ...
# 0              100202
# 0             7240837
# 0            14715067
# 0             1596687
# 0              180590
#
# [812 rows x 20 columns]

# %%
df.head()
# Out:
#                                       belongs_to_collection  \
# budget
# 14000000  [{'id': 313576, 'name': 'Hot Tub Time Machine ...
# 40000000  [{'id': 107674, 'name': 'The Princess Diaries ...
# 3300000                                                 NaN
# 1200000                                                 NaN
# 0                                                       NaN
#
#                                                      genres  \
# budget
# 14000000                     [{'id': 35, 'name': 'Comedy'}]
# 40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 3300000                       [{'id': 18, 'name': 'Drama'}]
# 1200000   [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 0         [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                                    homepage    imdb_id original_language  \
# budget
# 14000000                                NaN  tt2637294                en
# 40000000                                NaN  tt0368933                en
# 3300000   http://sonyclassics.com/whiplash/  tt2582802                en
# 1200000          http://kahaanithefilm.com/  tt1821480                hi
# 0                                       NaN  tt1380152                ko
#
#                                     original_title  \
# budget
# 14000000                    Hot Tub Time Machine 2
# 40000000  The Princess Diaries 2: Royal Engagement
# 3300000                                   Whiplash
# 1200000                                    Kahaani
# 0                                             마린보이
#
#                                                    overview  popularity  \
# budget
# 14000000  When Lou, who has become the "father of the In...    6.575393
# 40000000  Mia Thermopolis is now a college graduate and ...    8.248895
# 3300000   Under the direction of a ruthless instructor, ...   64.299990
# 1200000   Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936
# 0         Marine Boy is the story of a former national s...    1.148070
#
#                                        production_companies  \
# budget
# 14000000  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 40000000        [{'name': 'Walt Disney Pictures', 'id': 2}]
# 3300000   [{'name': 'Bold Films', 'id': 2266}, {'name': ...
# 1200000                                                 NaN
# 0                                                       NaN
#
#                                        production_countries release_date  \
# budget
# 14000000  [{'iso_3166_1': 'US', 'name': 'United States o...      2/20/15
# 40000000  [{'iso_3166_1': 'US', 'name': 'United States o...       8/6/04
# 3300000   [{'iso_3166_1': 'US', 'name': 'United States o...     10/10/14
# 1200000             [{'iso_3166_1': 'IN', 'name': 'India'}]       3/9/12
# 0             [{'iso_3166_1': 'KR', 'name': 'South Korea'}]       2/5/09
#
#           runtime                                   spoken_languages  \
# budget
# 14000000     93.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 40000000    113.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3300000     105.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1200000     122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 0           118.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]
#
#             status                                            tagline  \
# budget
# 14000000  Released  The Laws of Space and Time are About to be Vio...
# 40000000  Released  It can take a lifetime to find true love; she'...
# 3300000   Released    The road to greatness can take you to the edge.
# 1200000   Released                                                NaN
# 0         Released                                                NaN
#
#                                              title  \
# budget
# 14000000                    Hot Tub Time Machine 2
# 40000000  The Princess Diaries 2: Royal Engagement
# 3300000                                   Whiplash
# 1200000                                    Kahaani
# 0                                       Marine Boy
#
#                                                    Keywords  \
# budget
# 14000000  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 40000000  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 3300000   [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 1200000   [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 0                                                       NaN
#
#                                                        cast     revenue  \
# budget
# 14000000  [{'cast_id': 4, 'character': 'Lou', 'credit_id...         NaN
# 40000000  [{'cast_id': 1, 'character': 'Mia Thermopolis'...         NaN
# 3300000   [{'cast_id': 5, 'character': 'Andrew Neimann',...  13092000.0
# 1200000   [{'cast_id': 1, 'character': 'Vidya Bagchi', '...  16000000.0
# 0         [{'cast_id': 3, 'character': 'Chun-soo', 'cred...   3923970.0
#
#           movies_profit
# budget
# 14000000       -1685349
# 40000000       55149435
# 3300000         9792000
# 1200000        14800000
# 0               3923970

# %%
df['runtime'].sum()
# Out:
# 323354.0

# %%
print(f" The shortest movie length is {df['runtime'].min()}")
print(f" The largest movie length is {df['runtime'].max()}")
# Out:
#  The shortest movie length is 0.0
#  The largest movie length is 338.0

# %%
df[df['runtime']== 0.0]
# Out:
#                                       belongs_to_collection  \
# budget
# 6843500                                                 NaN
# 0                                                       NaN
# 0                                                       NaN
# 11000000                                                NaN
# 0                                                       NaN
# 750000                                                  NaN
# 0                                                       NaN
# 5000000                                                 NaN
# 3500000   [{'id': 106790, 'name': 'Hooked Collection', '...
# 0                                                       NaN
# 0                                                       NaN
# 5579750   [{'id': 188197, 'name': 'Cetto La Qualunque - ...
#
#                                                      genres  \
# budget
# 6843500                      [{'id': 35, 'name': 'Comedy'}]
# 0         [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 0                            [{'id': 35, 'name': 'Comedy'}]
# 11000000                     [{'id': 35, 'name': 'Comedy'}]
# 0                           [{'id': 37, 'name': 'Western'}]
# 750000    [{'id': 80, 'name': 'Crime'}, {'id': 35, 'name...
# 0         [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 5000000   [{'id': 28, 'name': 'Action'}, {'id': 10749, '...
# 3500000   [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 0                        [{'id': 10749, 'name': 'Romance'}]
# 0         [{'id': 14, 'name': 'Fantasy'}, {'id': 27, 'na...
# 5579750                      [{'id': 35, 'name': 'Comedy'}]
#
#                            homepage    imdb_id original_language  \
# budget
# 6843500                         NaN  tt2550838                it
# 0                               NaN  tt0768690                ru
# 0                               NaN  tt2604346                es
# 11000000                        NaN  tt2076251                it
# 0                               NaN  tt0072785                it
# 750000                          NaN  tt3805180                ru
# 0         http://www.vt4.be/vermist  tt1133617                en
# 5000000                         NaN  tt0477337                ru
# 3500000                         NaN  tt1620549                ru
# 0                               NaN  tt3956312                en
# 0                               NaN  tt0278675                fr
# 5579750                         NaN  tt2456720                it
#
#                                original_title  \
# budget
# 6843500      Il peggior Natale della mia vita
# 0                     А поутру они проснулись
# 0                        ¿Quién mató a Bambi?
# 11000000  La peggior settimana della mia vita
# 0                                Cipolla Colt
# 750000                            Все и сразу
# 0                                     Vermist
# 5000000                           Mechenosets
# 3500000               Na Igre 2. Novyy Uroven
# 0                                        同桌的妳
# 0                                  Revelation
# 5579750             Tutto tutto niente niente
#
#                                                    overview  popularity  \
# budget
# 6843500                                                 NaN    3.800073
# 0                                                       NaN    0.402368
# 0         It tells the story of two young friends who mu...    1.926826
# 11000000                                                NaN    5.010563
# 0         Onion Jack (Franco Nero) has bought a piece of...    1.623440
# 750000                                                  NaN    0.201582
# 0         Five members of the Missing Persons Task Force...    0.229233
# 5000000                                                 NaN    0.414793
# 3500000   The continuation of the adventures of the hero...    0.884241
# 0         In the summer of 1993, timid and shy Zhou Xiao...    0.504000
# 0         Since A.D. 50, a mysterious sacred artifact kn...    0.625099
# 5579750                                                 NaN    2.208906
#
#                                        production_companies  \
# budget
# 6843500   [{'name': 'Colorado Film Production', 'id': 10...
# 0         [{'name': 'Роскинопрокат', 'id': 14650}, {'nam...
# 0         [{'name': 'Televisión Española (TVE)', 'id': 6...
# 11000000  [{'name': 'Colorado Film Production', 'id': 10...
# 0         [{'name': 'Compagnia Cinematografica Champion'...
# 750000    [{'name': 'Кинокомпания «Lunapark»', 'id': 420...
# 0                                                       NaN
# 5000000          [{'name': 'Kinokompaniya CTB', 'id': 886}]
# 3500000                                                 NaN
# 0                [{'name': 'Enlight Pictures', 'id': 4053}]
# 0         [{'name': 'Romulus Films', 'id': 3632}, {'name...
# 5579750   [{'name': 'Fandango', 'id': 2441}, {'name': 'R...
#
#                                        production_countries release_date  \
# budget
# 6843500             [{'iso_3166_1': 'IT', 'name': 'Italy'}]     12/22/12
# 0                  [{'iso_3166_1': 'RU', 'name': 'Russia'}]      12/4/03
# 0                   [{'iso_3166_1': 'ES', 'name': 'Spain'}]     11/15/13
# 11000000            [{'iso_3166_1': 'IT', 'name': 'Italy'}]     10/27/11
# 0         [{'iso_3166_1': 'IT', 'name': 'Italy'}, {'iso_...      8/25/75
# 750000             [{'iso_3166_1': 'RU', 'name': 'Russia'}]       6/5/14
# 0                 [{'iso_3166_1': 'BE', 'name': 'Belgium'}]       1/1/07
# 5000000            [{'iso_3166_1': 'RU', 'name': 'Russia'}]     10/12/06
# 3500000            [{'iso_3166_1': 'RU', 'name': 'Russia'}]      4/15/10
# 0                   [{'iso_3166_1': 'CN', 'name': 'China'}]      4/25/14
# 0          [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]      4/12/01
# 5579750             [{'iso_3166_1': 'IT', 'name': 'Italy'}]     11/30/12
#
#           runtime                             spoken_languages    status  \
# budget
# 6843500       0.0    [{'iso_639_1': 'it', 'name': 'Italiano'}]  Released
# 0             0.0     [{'iso_639_1': 'ru', 'name': 'Pусский'}]  Released
# 0             0.0     [{'iso_639_1': 'es', 'name': 'Español'}]  Released
# 11000000      0.0    [{'iso_639_1': 'it', 'name': 'Italiano'}]  Released
# 0             0.0     [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 750000        0.0     [{'iso_639_1': 'ru', 'name': 'Pусский'}]  Released
# 0             0.0  [{'iso_639_1': 'nl', 'name': 'Nederlands'}]  Released
# 5000000       0.0     [{'iso_639_1': 'ru', 'name': 'Pусский'}]  Released
# 3500000       0.0     [{'iso_639_1': 'ru', 'name': 'Pусский'}]  Released
# 0             0.0         [{'iso_639_1': 'zh', 'name': '普通话'}]  Released
# 0             0.0                                          NaN  Released
# 5579750       0.0    [{'iso_639_1': 'it', 'name': 'Italiano'}]  Released
#
#          tagline                                 title  \
# budget
# 6843500      NaN        The Worst Christmas of My Life
# 0            NaN               А поутру они проснулись
# 0            NaN                  ¿Quién mató a Bambi?
# 11000000     NaN   La peggior settimana della mia vita
# 0            NaN                           Cry, Onion!
# 750000       NaN                           All at Once
# 0            NaN                               Missing
# 5000000      NaN                           Mechenosets
# 3500000      NaN  Hooked on the Game 2. The Next Level
# 0            NaN                      My Old Classmate
# 0            NaN                            Revelation
# 5579750      NaN             Tutto tutto niente niente
#
#                                                    Keywords  \
# budget
# 6843500                                                 NaN
# 0         [{'id': 4897, 'name': 'multiple character'}, {...
# 0         [{'id': 1930, 'name': 'kidnapping'}, {'id': 97...
# 11000000                                                NaN
# 0             [{'id': 156212, 'name': 'spaghetti western'}]
# 750000    [{'id': 642, 'name': 'robbery'}, {'id': 231149...
# 0                                                       NaN
# 5000000                                                 NaN
# 3500000                                                 NaN
# 0                                                       NaN
# 0                                                       NaN
# 5579750   [{'id': 8201, 'name': 'satire'}, {'id': 33501,...
#
#                                                        cast     revenue  \
# budget
# 6843500   [{'cast_id': 2, 'character': 'Alberto', 'credi...  10703234.0
# 0         [{'cast_id': 8, 'character': '', 'credit_id': ...    234748.0
# 0         [{'cast_id': 3, 'character': 'David', 'credit_...    850259.0
# 11000000  [{'cast_id': 4, 'character': 'Paolo', 'credit_...  12935800.0
# 0         [{'cast_id': 14, 'character': 'Onion Stark', '...  39598448.0
# 750000    [{'cast_id': 3, 'character': 'Viktor', 'credit...         3.0
# 0         [{'cast_id': 2, 'character': 'Murat Hoxha', 'c...         1.0
# 5000000   [{'cast_id': 2, 'character': 'Sasha', 'credit_...   3919731.0
# 3500000   [{'cast_id': 10, 'character': 'Vampire', 'cred...   2294357.0
# 0         [{'cast_id': 0, 'character': 'Zhou Xiao Zhi', ...  76000000.0
# 0         [{'cast_id': 1, 'character': 'Jake Martel', 'c...  10000000.0
# 5579750   [{'cast_id': 1, 'character': 'Cetto La Qualunq...   8927600.0
#
#           movies_profit
# budget
# 6843500         3859734
# 0                234748
# 0                850259
# 11000000        1935800
# 0              39598448
# 750000          -749997
# 0                     1
# 5000000        -1080269
# 3500000        -1205643
# 0              76000000
# 0              10000000
# 5579750         3347850

# %%
def to_uppercase(column):
  return column.upper()
df['Capitalized_title'] = df['title'].apply(to_uppercase)
df.head()
# Out:
#                                       belongs_to_collection  \
# budget
# 14000000  [{'id': 313576, 'name': 'Hot Tub Time Machine ...
# 40000000  [{'id': 107674, 'name': 'The Princess Diaries ...
# 3300000                                                 NaN
# 1200000                                                 NaN
# 0                                                       NaN
#
#                                                      genres  \
# budget
# 14000000                     [{'id': 35, 'name': 'Comedy'}]
# 40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 3300000                       [{'id': 18, 'name': 'Drama'}]
# 1200000   [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 0         [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                                    homepage    imdb_id original_language  \
# budget
# 14000000                                NaN  tt2637294                en
# 40000000                                NaN  tt0368933                en
# 3300000   http://sonyclassics.com/whiplash/  tt2582802                en
# 1200000          http://kahaanithefilm.com/  tt1821480                hi
# 0                                       NaN  tt1380152                ko
#
#                                     original_title  \
# budget
# 14000000                    Hot Tub Time Machine 2
# 40000000  The Princess Diaries 2: Royal Engagement
# 3300000                                   Whiplash
# 1200000                                    Kahaani
# 0                                             마린보이
#
#                                                    overview  popularity  \
# budget
# 14000000  When Lou, who has become the "father of the In...    6.575393
# 40000000  Mia Thermopolis is now a college graduate and ...    8.248895
# 3300000   Under the direction of a ruthless instructor, ...   64.299990
# 1200000   Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936
# 0         Marine Boy is the story of a former national s...    1.148070
#
#                                        production_companies  \
# budget
# 14000000  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 40000000        [{'name': 'Walt Disney Pictures', 'id': 2}]
# 3300000   [{'name': 'Bold Films', 'id': 2266}, {'name': ...
# 1200000                                                 NaN
# 0                                                       NaN
#
#                                        production_countries  ... runtime  \
# budget                                                       ...
# 14000000  [{'iso_3166_1': 'US', 'name': 'United States o...  ...    93.0
# 40000000  [{'iso_3166_1': 'US', 'name': 'United States o...  ...   113.0
# 3300000   [{'iso_3166_1': 'US', 'name': 'United States o...  ...   105.0
# 1200000             [{'iso_3166_1': 'IN', 'name': 'India'}]  ...   122.0
# 0             [{'iso_3166_1': 'KR', 'name': 'South Korea'}]  ...   118.0
#
#                                            spoken_languages    status  \
# budget
# 14000000           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 40000000           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3300000            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1200000   [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 0                  [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]  Released
#
#                                                     tagline  \
# budget
# 14000000  The Laws of Space and Time are About to be Vio...
# 40000000  It can take a lifetime to find true love; she'...
# 3300000     The road to greatness can take you to the edge.
# 1200000                                                 NaN
# 0                                                       NaN
#
#                                              title  \
# budget
# 14000000                    Hot Tub Time Machine 2
# 40000000  The Princess Diaries 2: Royal Engagement
# 3300000                                   Whiplash
# 1200000                                    Kahaani
# 0                                       Marine Boy
#
#                                                    Keywords  \
# budget
# 14000000  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 40000000  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 3300000   [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 1200000   [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 0                                                       NaN
#
#                                                        cast     revenue  \
# budget
# 14000000  [{'cast_id': 4, 'character': 'Lou', 'credit_id...         NaN
# 40000000  [{'cast_id': 1, 'character': 'Mia Thermopolis'...         NaN
# 3300000   [{'cast_id': 5, 'character': 'Andrew Neimann',...  13092000.0
# 1200000   [{'cast_id': 1, 'character': 'Vidya Bagchi', '...  16000000.0
# 0         [{'cast_id': 3, 'character': 'Chun-soo', 'cred...   3923970.0
#
#           movies_profit                         Capitalized_title
# budget
# 14000000       -1685349                    HOT TUB TIME MACHINE 2
# 40000000       55149435  THE PRINCESS DIARIES 2: ROYAL ENGAGEMENT
# 3300000         9792000                                  WHIPLASH
# 1200000        14800000                                   KAHAANI
# 0               3923970                                MARINE BOY
#
# [5 rows x 21 columns]

# %%
def add_two_numbers(a,b):
  return a+b
x = lambda a,b : a+b
x(1,5)
# Out:
# 6

# %%
def revised_profit(revenue,budget):
  if revenue > 0 :
    new_profit = revenue - budget
  else:
    new_profit = np.nan
