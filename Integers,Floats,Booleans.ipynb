# %% [markdown]
# # Integers and Floats

# %%
2+1
# Out:
# 3

# %%
2-5
# Out:
# -3

# %%
2*2
# Out:
# 4

# %%
3/2
# Out:
# 1.5

# %%
7//3
# Out:
# 2

# %%
2**5
# Out:
# 32

# %%
15%6
# Out:
# 3

# %%
2+10*10+3
# Out:
# 105

# %%
2+10*(10+3)
# Out:
# 132

# %%
4E3
# Out:
# 4000.0

# %% [markdown]
# # Variable

# %%
x=5
x
# Out:
# 5

# %%
y=6.4
y
# Out:
# 6.4

# %%
print(y)
# Out:
# 6.4

# %%
z = x+y
print(z)
# Out:
# 11.4

# %%
z= x-y
print(z)
# Out:
# -1.4000000000000004

# %%
type(y)
# Out:
# float

# %%
z = x*y
print(z)
type(z)
# Out:
# 32.0
# float

# %%
z= x/y
print(z)
type(z)
# Out:
# 0.78125
# float

# %%
z= x//y
print(z)
# Out:
# 0.0

# %%
1oNone = 4
# Out:
#   File "<ipython-input-23-5af1d05f4ba0>", line 1
#     1oNone = 4
#     ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# # Boolean Variable

# %%
boolean_variable = False
type(boolean_variable)
# Out:
# bool

# %%
boolean_variable
# Out:
# False

# %%
2==3
# Out:
# False

# %%
2==0
# Out:
# False

# %%
2!=0
# Out:
# True

# %%
2!=2
# Out:
# False

# %%
a=3
b=2
a>b
# Out:
# True

# %%
a==3
# Out:
# True

# %%
b>4
# Out:
# False

# %%
10<45
# Out:
# True

# %%
4<2
# Out:
# False

# %%
3>=2
# Out:
# True

# %%
4>=4
# Out:
# True

# %%
3<=0
# Out:
# False

# %%
1<=2
# Out:
# True
