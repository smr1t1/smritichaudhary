# %%
my_list = [1,2,3,4]
print (my_list)
# Out:
# [1, 2, 3, 4]

# %%
type(my_list)
# Out:
# list

# %%
my_list = ['A string ' ,23, 100.232,'0',True]
my_list
# Out:
# ['A string ', 23, 100.232, '0', True]

# %%
len(my_list)
# Out:
# 5

# %%
loss_function = ['Mean Absolute Error','Mean Squared Error','Hubber Loss','Log Loss','Hinge Loss']

# %%
print (loss_function[0])
# Out:
# Mean Absolute Error

# %%
print (loss_function[3])
# Out:
# Log Loss

# %%
print (loss _function[6])
# Out:
#   File "<ipython-input-25-809411915551>", line 1
#     print (loss _function[6])
#            ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print (loss_function [-1])
# Out:
# Hinge Loss

# %%
print (loss_function[-3])
# Out:
# Hubber Loss

# %%
print (loss_function)
# Out:
# ['Mean Absolute Error', 'Mean Squared Error', 'Hubber Loss', 'Log Loss', 'Hinge Loss']

# %%
loss_function[1:4]
# Out:
# ['Mean Squared Error', 'Hubber Loss', 'Log Loss']

# %%
loss_function[2:]
# Out:
# ['Hubber Loss', 'Log Loss', 'Hinge Loss']

# %%
loss_function[:4]
# Out:
# ['Mean Absolute Error', 'Mean Squared Error', 'Hubber Loss', 'Log Loss']

# %%
print (loss_function[:])
# Out:
# ['Mean Absolute Error', 'Mean Squared Error', 'Hubber Loss', 'Log Loss', 'Hinge Loss']

# %%
loss_function[-4:]
# Out:
# ['Mean Squared Error', 'Hubber Loss', 'Log Loss', 'Hinge Loss']

# %%
print(loss_function)
# Out:
# ['Mean Absolute Error', 'Mean Squared Error', 'Hubber Loss', 'Log Loss', 'Hinge Loss']

# %%
loss_function +['kullback -leibler']
# Out:
# ['Mean Absolute Error',
#  'Mean Squared Error',
#  'Hubber Loss',
#  'Log Loss',
#  'Hinge Loss',
#  'kullback -leibler']

# %%
print (loss_function)
# Out:
# ['Mean Absolute Error', 'Mean Squared Error', 'Hubber Loss', 'Log Loss', 'Hinge Loss']

# %%
loss_function = loss_function + ['kullback -leibler']

# %%
len (loss_function*5)
# Out:
# 55

# %%
print (loss_function)
# Out:
# ['Mean Absolute Error', 'Mean Squared Error', 'Hubber Loss', 'Log Loss', 'Hinge Loss', 'kullback -leibler', 'kullback -leibler', 'kullback -leibler', 'kullback -leibler', 'kullback -leibler', 'kullback -leibler']

# %%
len(loss_function)
# Out:
# 11

# %%
new_list =[6,9,1,3,5,5]
min(new_list)
# Out:
# 1

# %%
my_new_list = ['c','b','z','y','m']
min(my_new_list)
# Out:
# 'b'

# %%
new_list = ['Argue','Burglar','Zarent','Linear','shape']
max(new_list)
# Out:
# 'shape'

# %%
new_list =[6,9,1,3,5,5]
sum(new_list)
# Out:
# 29

# %%
(new_list)
# Out:
# [6, 9, 1, 3, 5, 5]

# %%
sorted(new_list)
# Out:
# [1, 3, 5, 5, 6, 9]

# %%
print (new_list)
# Out:
# [6, 9, 1, 3, 5, 5]

# %%
(new_list) = ['Argue','Burglar','Zarent','Linear','shape']
sorted(new_list)
# Out:
# ['Argue', 'Burglar', 'Linear', 'Zarent', 'shape']

# %%
print (new_list)
# Out:
# ['Argue', 'Burglar', 'Zarent', 'Linear', 'shape']

# %%
sorted(new_list, reverse= True)
# Out:
# ['shape', 'Zarent', 'Linear', 'Burglar', 'Argue']

# %%
sorted (new_list)
# Out:
# ['Argue', 'Burglar', 'Linear', 'Zarent', 'shape']

# %%
(new_list)
# Out:
# ['Argue', 'Burglar', 'Zarent', 'Linear', 'shape']

# %%
my_list = [1,2,3,1,1,1,1,3,10,5,8]
my_list
# Out:
# [1, 2, 3, 1, 1, 1, 1, 3, 10, 5, 8]

# %%
len(my_list)
# Out:
# 11

# %%
my_list.append('Append me!')
print (my_list)
# Out:
# [1, 2, 3, 1, 1, 1, 1, 3, 10, 5, 8, 'Append me!', 'Append me!']

# %%
len (my_list)
# Out:
# 13

# %%
my_list.append(2.73)
print( my_list)
len(my_list)
# Out:
# [1, 2, 3, 1, 1, 1, 1, 3, 10, 5, 8, 'Append me!', 'Append me!', 2.73, 2.73, 2.73]
# 16

# %%
my_list.append([1,2,3])
len (my_list)
# Out:
# 18

# %%
my_list.append([10,[19,20],30])
my_list
# Out:
# [1,
#  2,
#  3,
#  1,
#  1,
#  1,
#  1,
#  3,
#  10,
#  5,
#  8,
#  'Append me!',
#  'Append me!',
#  2.73,
#  2.73,
#  2.73,
#  [1, 2, 3],
#  [1, 2, 3],
#  [10, [19, 20], 30],
#  [10, [19, 20], 30]]

# %%
 print (my_list)
# Out:
# [1, 2, 3, 1, 1, 1, 1, 3, 10, 5, 8, 'Append me!', 'Append me!', 2.73, 2.73, 2.73, [1, 2, 3], [1, 2, 3], [10, [19, 20], 30], [10, [19, 20], 30]]

# %%
my_list.extend(['wubba', 'Lubba','Dub Dub'])
print (my_list)
# Out:
# [1, 2, 3, 1, 1, 1, 1, 3, 10, 5, 8, 'Append me!', 'Append me!', 2.73, 2.73, 2.73, [1, 2, 3], [1, 2, 3], [10, [19, 20], 30], [10, [19, 20], 30], 'wubba', 'Lubba', 'Dub Dub']

# %%
len (my_list)
# Out:
# 23

# %%
print (my_list)
# Out:
# [1, 2, 3, 1, 1, 1, 1, 3, 10, 5, 8, 'Append me!', 'Append me!', 2.73, 2.73, 2.73, [1, 2, 3], [1, 2, 3], [10, [19, 20], 30], [10, [19, 20], 30], 'wubba', 'Lubba', 'Dub Dub']

# %%
my_list.pop()
# Out:
# 'Dub Dub'

# %%
print(my_list)
# Out:
# [1, 3, 1, 1, 1, 1, 3, 10, 5, 8, 'Append me!', 'Append me!', 2.73, 2.73, 2.73, [1, 2, 3], [1, 2, 3], [10, [19, 20], 30], [10, [19, 20], 30], 'wubba', 'Lubba']

# %%
my_list.pop(1)
# Out:
# 2

# %%
len(my_list)
# Out:
# 21

# %%
print (my_list)
# Out:
# [1, 3, 1, 1, 1, 1, 3, 10, 5, 8, 'Append me!', 'Append me!', 2.73, 2.73, 2.73, [1, 2, 3], [1, 2, 3], [10, [19, 20], 30], [10, [19, 20], 30], 'wubba', 'Lubba']

# %%
my_list.remove([1,2,3])
print (my_list)
# Out:
# [1, 3, 1, 1, 1, 1, 3, 10, 5, 8, 'Append me!', 'Append me!', 2.73, 2.73, 2.73, [10, [19, 20], 30], [10, [19, 20], 30], 'wubba', 'Lubba']

# %%
my_list.remove(1)
print (my_list)
# Out:
# [3, 1, 1, 1, 1, 3, 10, 5, 8, 'Append me!', 'Append me!', 2.73, 2.73, 2.73, [10, [19, 20], 30], [10, [19, 20], 30], 'wubba', 'Lubba']

# %%
len(my_list)
# Out:
# 18

# %%
my_list.clear
# Out:
# <function list.clear()>

# %%
print (my_list)
# Out:
# [3, 1, 1, 1, 1, 3, 10, 5, 8, 'Append me!', 'Append me!', 2.73, 2.73, 2.73, [10, [19, 20], 30], [10, [19, 20], 30], 'wubba', 'Lubba']

# %%
 my_list.count(11)
# Out:
# 0

# %%
print (my_list)
# Out:
# [3, 1, 1, 1, 1, 3, 10, 5, 8, 'Append me!', 'Append me!', 2.73, 2.73, 2.73, [10, [19, 20], 30], [10, [19, 20], 30], 'wubba', 'Lubba']

# %%
my_list.index('wubba')
# Out:
# 16

# %%
new_list= [6,9,1,3,5]
new_list.sort()
print (new_list)
# Out:
# [1, 3, 5, 6, 9]

# %%
new_list.sort(reverse =True)
print (new_list)
# Out:
# [9, 6, 5, 3, 1]

# %%
boolean_list = [True,False]
boolean_list.sort(reverse=True)
print(boolean_list)
# Out:
# [True, False]

# %%
my_list =[1,1,1,1,1.43,2,3,3,5,8,10,'Lubba','Dub Dub']
print(my_list)
# Out:
# [1, 1, 1, 1, 1.43, 2, 3, 3, 5, 8, 10, 'Lubba', 'Dub Dub']

# %%
my_list.reverse()

# %%
print(my_list)
# Out:
# [1, 1, 1, 1, 1.43, 2, 3, 3, 5, 8, 10, 'Lubba', 'Dub Dub']

# %%
lst_1 =[1,2,3]
lst_2 = ['b','a','d']
lst_3 =[7,8,9]
list_of_lists = [lst_1,lst_2,lst_3]
print( list_of_lists )
# Out:
# [[1, 2, 3], ['b', 'a', 'd'], [7, 8, 9]]

# %%
type(list_of_lists)
# Out:
# list

# %%
list_of_lists[1]
# Out:
# ['b', 'a', 'd']

# %%
# Out:
#   File "<ipython-input-130-4fc8238f6d77>", line 1
#     list_of_lists[1][1][][][]
#                         ^
# SyntaxError: invalid syntax
