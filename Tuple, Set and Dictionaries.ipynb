# %% [markdown]
# # Tuples

# %%
my_tuple = (1,'a',3)
print(my_tuple)
# Out:
# (1, 'a', 3)

# %%
type(my_tuple)
# Out:
# tuple

# %%
another_tuple = ('one',2, 4.53, 'asbc')
another_tuple
# Out:
# ('one', 2, 4.53, 'asbc')

# %%
my_list = [1]
type(my_list)
# Out:
# list

# %%
my_tuple = (1,)
type(my_tuple)
# Out:
# tuple

# %%
my_tuple = 1,2,3
type(my_tuple)
# Out:
# tuple

# %%
my_tuple = (1,2,3,4)
len(my_tuple)
# Out:
# 4

# %% [markdown]
# # Tuple Indexing

# %%
print(another_tuple)
# Out:
# ('one', 2, 4.53, 'asbc')

# %%
another_tuple[0]
# Out:
# 'one'

# %%
another_tuple[3]
# Out:
# 'asbc'

# %%
another_tuple[-1]
# Out:
# 'asbc'

# %%
another_tuple[-3]
# Out:
# 2

# %% [markdown]
# # Tuple Slicing

# %%
print(another_tuple)
# Out:
# ('one', 2, 4.53, 'asbc')

# %%
another_tuple[1:3]
# Out:
# (2, 4.53)

# %%
another_tuple[2:]
# Out:
# (4.53, 'asbc')

# %%
another_tuple[:6]
# Out:
# ('one', 2, 4.53, 'asbc')

# %%
another_tuple
# Out:
# ('one', 2, 4.53, 'asbc')

# %%
another_tuple[-4:]
# Out:
# ('one', 2, 4.53, 'asbc')

# %%
another_tuple[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-3d51a942c11d> in <cell line: 0>()
# ----> 1 another_tuple[5]
#
# IndexError: tuple index out of range

# %%
len(another_tuple)
# Out:
# 4

# %%
random_tuple = (1,5,6,2)
sorted(random_tuple)
# Out:
# [1, 2, 5, 6]

# %%
my_tuple =(1,2,3,4,5,6,1,1,2)
my_tuple.index(2)
# Out:
# 1

# %%
my_tuple.count(2)
# Out:
# 2

# %%
my_tuple.count(1)
# Out:
# 3

# %%
print(my_tuple)
# Out:
# (1, 2, 3, 4, 5, 6, 1, 1, 2)

# %%
my_tuple[0]
# Out:
# 1

# %%
my_tuple[0] = 'change'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-1113c19e61ee> in <cell line: 0>()
# ----> 1 my_tuple[0] = 'change'
#
# TypeError: 'tuple' object does not support item assignment

# %%
my_list = [5,7,9,3,2]
my_list
# Out:
# [5, 7, 9, 3, 2]

# %%
my_list[0] = 1
my_list
# Out:
# [1, 7, 9, 3, 2]

# %%
my_tuple.append('Great!')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-762f4e61335a> in <cell line: 0>()
# ----> 1 my_tuple.append('Great!')
#
# AttributeError: 'tuple' object has no attribute 'append'

# %% [markdown]
# # Set

# %%
empty_set = set()
type(empty_set)
# Out:
# set

# %%
non_empty_set = {1,6,4,'abc'}
type(non_empty_set)
# Out:
# set

# %%
my_object = {}
type(my_object)
# Out:
# dict

# %%
my_set = set()
type(my_set)
# Out:
# set

# %%
my_list = [1,1,2,2,3,4,5,6,1,1]
my_set = set(my_list)
my_set
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
my_set = {1,2,(3,4)}
my_set = {1,2,(2,3)}
my_set
# Out:
# {(2, 3), 1, 2}

# %%
my_set = {1,2,{3,5}}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-76afaabf4ea0> in <cell line: 0>()
# ----> 1 my_set = {1,2,{3,5}}
#
# TypeError: unhashable type: 'set'

# %%
my_set
# Out:
# {(2, 3), 1, 2}

# %%
my_set = set()
my_set.add('a')


my_set
# Out:
# {'a'}

# %%
my_set.add(2)

print(my_set)
# Out:
# {2, 'a'}

# %%
x.add(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-b0343c13fe54> in <cell line: 0>()
# ----> 1 x.add(1)
#
# NameError: name 'x' is not defined

# %%
my_set = {5,7,9,3}
my_set.update([2, 3, 4])
print(my_set)
# Out:
# {2, 3, 4, 5, 7, 9}

# %%
non_empty_set = {1,5,6,73,2}
non_empty_set.remove(5)
non_empty_set
# Out:
# {1, 2, 6, 73}

# %%
non_empty_set.remove(45)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-a4e6701c6396> in <cell line: 0>()
# ----> 1 non_empty_set.remove(45)
#
# KeyError: 45

# %%
A = {1,2,3,4,5}
B= {4,5,6,7,8}
A.union(B)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
A
# Out:
# {1, 2, 3, 4, 5}

# %%
A|B
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
A= {1,2,3,4,5}
B= {4,5,6,7,8}
A.intersection(B)
# Out:
# {4, 5}

# %%
A & B
# Out:
# {4, 5}

# %%
A= {1,2,3,4,5,}
B= {4,5,6,7,8}
A.difference(B)
# Out:
# {1, 2, 3}

# %%
A-B
# Out:
# {1, 2, 3}

# %%
B.difference(A)
# Out:
# {6, 7, 8}

# %%
B-A
# Out:
# {6, 7, 8}

# %%
A= {1,2,3,4,5}
B= {4,5,6,7,8}
A.symmetric_difference(B)
# Out:
# {1, 2, 3, 6, 7, 8}

# %%
A^B
# Out:
# {1, 2, 3, 6, 7, 8}

# %% [markdown]
# # Dictionaries

# %%
marvel_dict = {'Name': 'Thor', 'Place':'Asgard', 'Weapon':'Hammer', 1:2, 3 :'power', 'alibies' : ['Ironman', 'Captain America'],'abc' : {1:2,4:5} }
marvel_dict['Place']
# Out:
# 'Asgard'

# %%
type(marvel_dict)
# Out:
# dict

# %%
marvel_dict['Name']
# Out:
# 'Thor'

# %%
marvel_dict['Random']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-9f68b85bbfcd> in <cell line: 0>()
# ----> 1 marvel_dict['Random']
#
# KeyError: 'Random'

# %%
marvel_dict['Weapon']
# Out:
# 'Hammer'

# %%
marvel_dict['alibies']
# Out:
# ['Ironman', 'Captain America']

# %%
type(marvel_dict['abc'])
# Out:
# dict

# %%
marvel_dict.keys()
# Out:
# dict_keys(['Name', 'Place', 'Weapon', 1, 3, 'alibies', 'abc'])

# %%
list(marvel_dict.keys())
# Out:
# ['Name', 'Place', 'Weapon', 1, 3, 'alibies', 'abc']

# %%
print(marvel_dict)
# Out:
# {'Name': 'Thor', 'Place': 'Asgard', 'Weapon': 'Hammer', 1: 2, 3: 'power', 'alibies': ['Ironman', 'Captain America'], 'abc': {1: 2, 4: 5}}

# %%
list(marvel_dict.values())
# Out:
# ['Thor',
#  'Asgard',
#  'Hammer',
#  2,
#  'power',
#  ['Ironman', 'Captain America'],
#  {1: 2, 4: 5}]

# %%
marvel_dict.get('Place')
# Out:
# 'Asgard'

# %%
marvel_dict.get('Random')
marvel_dict.get('Random','Not Found')
# Out:
# 'Not Found'

# %%
marvel_dict['friend']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-6d5748fd78c2> in <cell line: 0>()
# ----> 1 marvel_dict['friend']
#
# KeyError: 'friend'

# %%
employee_dict = {'Name':'Sanket', 'Skills':['Python','Machine Learning','Deep Learing'],'Band':6.0,'Promotion Year':[2016,2018,2020]}
len(employee_dict)
# Out:
# 4

# %%
employee_dict['Skills']
# Out:
# ['Python', 'Machine Learning', 'Deep Learing']

# %%
employee_dict['Skills'][0]
# Out:
# 'Python'

# %%
employee_dict['Skills'][0].upper()
# Out:
# 'PYTHON'

# %%
employee_dict['Designation'] ='Senior Data Scientist'


employee_dict
# Out:
# {'Name': 'Sanket',
#  'Skills': ['Python', 'Machine Learning', 'Deep Learing'],
#  'Band': 6.0,
#  'Promotion Year': [2016, 2018, 2020],
#  'Designation': 'Senior Data Scientist'}

# %%
employee_dict.update({'Salary' : '2,000,000'})
employee_dict
# Out:
# {'Name': 'Sanket',
#  'Skills': ['Python', 'Machine Learning', 'Deep Learing'],
#  'Band': 6.0,
#  'Promotion Year': [2016, 2018, 2020],
#  'Designation': 'Senior Data Scientist',
#  'Salary': '2,000,000'}

# %%
employee_dict.update({'Name' : 'Varun Saini'})
employee_dict
# Out:
# {'Name': 'Varun Saini',
#  'Skills': ['Python', 'Machine Learning', 'Deep Learing'],
#  'Band': 6.0,
#  'Promotion Year': [2016, 2018, 2020],
#  'Designation': 'Senior Data Scientist',
#  'Salary': '2,000,000'}

# %%
employee_dict['Name']
# Out:
# 'Varun Saini'

# %%
employee_dict['Name']= employee_dict['Name'] + ' ' + 'Raj'
employee_dict
# Out:
# {'Name': 'Varun Saini Raj',
#  'Skills': ['Python', 'Machine Learning', 'Deep Learing'],
#  'Band': 6.0,
#  'Promotion Year': [2016, 2018, 2020],
#  'Designation': 'Senior Data Scientist',
#  'Salary': '2,000,000'}

# %%
country_list = ['India','Australia','United States','England']
city_list = ['New Delhi','Canberra','Washington DC','London']
country_city_list = list(zip(country_list,city_list))
country_city_list
# Out:
# [('India', 'New Delhi'),
#  ('Australia', 'Canberra'),
#  ('United States', 'Washington DC'),
#  ('England', 'London')]

# %%
dict(country_city_list)
# Out:
# {'India': 'New Delhi',
#  'Australia': 'Camberra',
#  'United States': 'Washington DC',
#  'England': 'London'}

# %%
country_city_tuples = [('India','New Delhi'),('Australia','Canberra'),('United States','Washington DC'),('England','London')]
country_city_dict = dict(country_city_tuples)
country_city_dict
# Out:
# {'India': 'New Delhi',
#  'Australia': 'Canberra',
#  'United States': 'Washington DC',
#  'England': 'London'}

# %%
country_city_dict.pop('England')
# Out:
# 'London'

# %%
country_city_dict
# Out:
# {'India': 'New Delhi',
#  'Australia': 'Canberra',
#  'United States': 'Washington DC'}

# %%
element_to_pop = country_city_dict.pop('England')
element_to_pop
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-81-c1878009bf8c> in <cell line: 0>()
# ----> 1 element_to_pop = country_city_dict.pop('England')
#       2 element_to_pop
#
# KeyError: 'England'

# %%
country_city_dict
# Out:
# {'India': 'New Delhi',
#  'Australia': 'Canberra',
#  'United States': 'Washington DC'}

# %%
name = ["Manjeet","Nikhil","Shambhavi"]
marks = [40,50,60]
mapped = zip(name,marks)
mapped

# %%
print(dict(mapped))
# Out:
# {'Manjeet': 40, 'Nikhil': 50, 'Shambhavi': 60}

# %%
name= ["Manjeet","Nikhil","Shambhavi"]
marks = [40,50,60,80]
mapped = zip(name,marks)
print(dict(mapped))
# Out:
# {'Manjeet': 40, 'Nikhil': 50, 'Shambhavi': 60}
